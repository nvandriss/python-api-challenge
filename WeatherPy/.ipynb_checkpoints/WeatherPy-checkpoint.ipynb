# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Find Weather Data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
   
weather_response = requests.get(query_url + city)
weather_json = weather_response.json()
print(json.dumps(weather_json))
# Out:
# {"coord": {"lon": 19.2345, "lat": -34.4187}, "weather": [{"id": 500, "main": "Rain", "description": "light rain", "icon": "10n"}], "base": "stations", "main": {"temp": 62.8, "feels_like": 62.73, "temp_min": 62.8, "temp_max": 63.9, "pressure": 1015, "humidity": 84, "sea_level": 1015, "grnd_level": 1011}, "visibility": 10000, "wind": {"speed": 10.13, "deg": 255, "gust": 13.6}, "rain": {"1h": 0.11}, "clouds": {"all": 80}, "dt": 1635527702, "sys": {"type": 2, "id": 2006131, "country": "ZA", "sunrise": 1635479076, "sunset": 1635527325}, "timezone": 7200, "id": 3366880, "name": "Hermanus", "cod": 200}

# %%
city_name = []
country = []
date = []
lat = []
lon = []
max_temp = []
humidity = []
cloudiness = []
windspeed = []

record_count = 1

print(f"Beginning Data Retrieval")
print(f"-------------------------")
    
for city in cities:
    try: 
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windspeed.append(response["wind"]["speed"])
        city_name2 = response["name"]
        print(f"Processing Record {record_count} : {city_name2}")    
        
        record_count += 1
    except:
        print("City not found. Skipping...") 
    continue
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 : Concarneau
# Processing Record 2 : Mataura
# Processing Record 3 : Vaini
# Processing Record 4 : Cape Town
# Processing Record 5 : Rikitea
# Processing Record 6 : Kapaa
# Processing Record 7 : Punta Arenas
# Processing Record 8 : Albany
# Processing Record 9 : Codrington
# Processing Record 10 : Acapulco de Juárez
# Processing Record 11 : Hilo
# Processing Record 12 : Hermanus
# Processing Record 13 : Souillac
# Processing Record 14 : Shelburne
# Processing Record 15 : Qui Nhon
# Processing Record 16 : Sembakung
# Processing Record 17 : Alofi
# City not found. Skipping...
# Processing Record 18 : Bluff
# Processing Record 19 : Bukachacha
# Processing Record 20 : Olafsvik
# Processing Record 21 : Fairbanks
# Processing Record 22 : Busselton
# Processing Record 23 : Bethel
# Processing Record 24 : Rockport
# Processing Record 25 : Kavieng
# Processing Record 26 : Saint Anthony
# Processing Record 27 : Tabuk
# Processing Record 28 : Bredasdorp
# Processing Record 29 : Faanui
# Processing Record 30 : Arraial do Cabo
# Processing Record 31 : Yellowknife
# Processing Record 32 : Kasongo
# Processing Record 33 : Chui
# Processing Record 34 : Sohbatpur
# Processing Record 35 : Puerto Ayora
# Processing Record 36 : Saint-Louis
# Processing Record 37 : Khor
# Processing Record 38 : Atuona
# Processing Record 39 : Kaihua
# Processing Record 40 : Port Alfred
# City not found. Skipping...
# Processing Record 41 : Nanortalik
# Processing Record 42 : Bayamo
# Processing Record 43 : Plátanos
# Processing Record 44 : Palmeirais
# Processing Record 45 : São Filipe
# Processing Record 46 : East London
# Processing Record 47 : Shaoyang
# Processing Record 48 : Valparaíso
# Processing Record 49 : Troitskoye
# Processing Record 50 : Labuhan
# Processing Record 51 : New Norfolk
# Processing Record 52 : Bardstown
# Processing Record 53 : Hobart
# Processing Record 54 : Ushuaia
# Processing Record 55 : Conde
# Processing Record 56 : Nikolskoye
# Processing Record 57 : Machinga
# Processing Record 58 : Carnarvon
# Processing Record 59 : Mehamn
# Processing Record 60 : Ormara
# Processing Record 61 : Vallenar
# Processing Record 62 : Mahébourg
# Processing Record 63 : Kaitangata
# Processing Record 64 : Kavaratti
# Processing Record 65 : Ribeira Grande
# Processing Record 66 : Tupik
# Processing Record 67 : Ji’an
# Processing Record 68 : Qaanaaq
# Processing Record 69 : Port Macquarie
# Processing Record 70 : Ponta do Sol
# Processing Record 71 : Sitka
# Processing Record 72 : Saint-Joseph
# Processing Record 73 : Tabou
# Processing Record 74 : Butaritari
# Processing Record 75 : Guánica
# Processing Record 76 : Grand Gaube
# Processing Record 77 : Blagoyevo
# Processing Record 78 : Faya
# Processing Record 79 : Rio Grande
# City not found. Skipping...
# Processing Record 80 : Muzhi
# Processing Record 81 : Igunga
# City not found. Skipping...
# Processing Record 82 : Kirensk
# Processing Record 83 : Lakes Entrance
# Processing Record 84 : Mar del Plata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 85 : Padang
# Processing Record 86 : Katsuura
# Processing Record 87 : Lahaina
# Processing Record 88 : Isangel
# Processing Record 89 : Boa Vista
# Processing Record 90 : Presidencia Roque Sáenz Peña
# Processing Record 91 : Newport
# Processing Record 92 : San Fernando del Valle de Catamarca
# Processing Record 93 : Berlevåg
# Processing Record 94 : Puerto Ayacucho
# Processing Record 95 : Tasiilaq
# Processing Record 96 : Klaksvík
# Processing Record 97 : Aktobe
# Processing Record 98 : Vestmannaeyjar
# Processing Record 99 : Hithadhoo
# Processing Record 100 : Broome
# Processing Record 101 : George Town
# Processing Record 102 : Coos Bay
# City not found. Skipping...
# Processing Record 103 : Jumla
# Processing Record 104 : Kiryat Gat
# City not found. Skipping...
# Processing Record 105 : Bambous Virieux
# Processing Record 106 : Enshi
# Processing Record 107 : Kangaatsiaq
# Processing Record 108 : Tiksi
# Processing Record 109 : Vila Franca do Campo
# Processing Record 110 : Rome
# Processing Record 111 : Khatanga
# Processing Record 112 : Bairiki Village
# Processing Record 113 : Upernavik
# Processing Record 114 : Santa Marta
# Processing Record 115 : Mackay
# Processing Record 116 : Aklavik
# Processing Record 117 : Ina
# Processing Record 118 : Talara
# Processing Record 119 : Talcahuano
# Processing Record 120 : Petrolina de Goiás
# City not found. Skipping...
# Processing Record 121 : Tommot
# Processing Record 122 : Saskylakh
# Processing Record 123 : Jiuquan
# Processing Record 124 : Tigil'
# City not found. Skipping...
# Processing Record 125 : Salalah
# City not found. Skipping...
# Processing Record 126 : Quatre Cocos
# Processing Record 127 : Geraldton
# Processing Record 128 : Sawtell
# Processing Record 129 : Norman Wells
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 130 : La Palma
# City not found. Skipping...
# Processing Record 131 : San Lorenzo
# Processing Record 132 : Cidreira
# City not found. Skipping...
# Processing Record 133 : Tilichiki
# City not found. Skipping...
# Processing Record 134 : São Miguel do Araguaia
# Processing Record 135 : Lompoc
# Processing Record 136 : Trincomalee
# Processing Record 137 : Port Hedland
# Processing Record 138 : Westport
# City not found. Skipping...
# Processing Record 139 : Wuwei
# Processing Record 140 : Bhādra
# City not found. Skipping...
# Processing Record 141 : Saint-Philippe
# Processing Record 142 : Zhigansk
# Processing Record 143 : Port Blair
# City not found. Skipping...
# Processing Record 144 : Paso de Carrasco
# Processing Record 145 : Ilulissat
# Processing Record 146 : Isla Mujeres
# Processing Record 147 : Lorengau
# Processing Record 148 : Tricase
# Processing Record 149 : Capaci
# Processing Record 150 : Avarua
# Processing Record 151 : Novopokrovka
# Processing Record 152 : Mahibadhoo
# Processing Record 153 : Sadao
# City not found. Skipping...
# Processing Record 154 : Ostrovnoy
# Processing Record 155 : Teya
# Processing Record 156 : Kununurra
# Processing Record 157 : La Ronge
# Processing Record 158 : Tarbagatay
# Processing Record 159 : Bubaque
# Processing Record 160 : Ayorou
# Processing Record 161 : Alice
# Processing Record 162 : Thompson
# Processing Record 163 : Sena Madureira
# Processing Record 164 : Hong Kong
# Processing Record 165 : Tuktoyaktuk
# Processing Record 166 : Richards Bay
# Processing Record 167 : Gornopravdinsk
# Processing Record 168 : Kuala Terengganu
# Processing Record 169 : Švenčionėliai
# Processing Record 170 : San Cristobal
# Processing Record 171 : Saint George
# Processing Record 172 : Krasnosel'kup
# Processing Record 173 : Chokurdakh
# Processing Record 174 : Tual
# Processing Record 175 : Pallasovka
# Processing Record 176 : Tuatapere
# Processing Record 177 : Severodvinsk
# Processing Record 178 : Nantucket
# Processing Record 179 : Bozoum
# City not found. Skipping...
# Processing Record 180 : Grindavik
# Processing Record 181 : Graaff-Reinet
# Processing Record 182 : Itoman
# Processing Record 183 : Bam
# Processing Record 184 : Entre Rios
# Processing Record 185 : Piranshahr
# Processing Record 186 : Damaturu
# Processing Record 187 : Zabaykal'sk
# Processing Record 188 : Noyabrsk
# Processing Record 189 : Margate
# Processing Record 190 : Sarana
# Processing Record 191 : Bay Saint Louis
# Processing Record 192 : Naze
# Processing Record 193 : Black River
# Processing Record 194 : Prince Rupert
# Processing Record 195 : Guerrero Negro
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 196 : Kandi
# Processing Record 197 : Cravo Norte
# Processing Record 198 : Lata
# Processing Record 199 : Tegul'det
# Processing Record 200 : Castro
# Processing Record 201 : Kahului
# Processing Record 202 : Clyde River
# Processing Record 203 : Pedernales
# Processing Record 204 : Ahipara
# Processing Record 205 : Ozernovskiy
# Processing Record 206 : Bemidji
# Processing Record 207 : Vila Velha
# Processing Record 208 : Boende
# Processing Record 209 : Iralaya
# Processing Record 210 : Te Anau
# Processing Record 211 : Havøysund
# Processing Record 212 : Kasempa
# City not found. Skipping...
# Processing Record 213 : Airai
# Processing Record 214 : Halifax
# Processing Record 215 : Arlit
# Processing Record 216 : Jamestown
# City not found. Skipping...
# Processing Record 217 : Telford
# Processing Record 218 : Dagda
# Processing Record 219 : Hay River
# Processing Record 220 : Clonmel
# Processing Record 221 : Elko
# Processing Record 222 : Pisco
# Processing Record 223 : Yulara
# Processing Record 224 : Eyl
# Processing Record 225 : Deputatsky
# City not found. Skipping...
# Processing Record 226 : Hurghada
# Processing Record 227 : Uravakonda
# Processing Record 228 : Provideniya
# Processing Record 229 : Le Port
# Processing Record 230 : Paciran
# Processing Record 231 : Ossora
# Processing Record 232 : Goderich
# Processing Record 233 : Lucapa
# Processing Record 234 : Anadyr
# Processing Record 235 : Qaqortoq
# Processing Record 236 : Biak
# Processing Record 237 : Kysyl-Syr
# Processing Record 238 : Yumen
# Processing Record 239 : Ardakān
# Processing Record 240 : Baruun-Urt
# Processing Record 241 : Delfzijl
# Processing Record 242 : Manacor
# Processing Record 243 : Naryan-Mar
# Processing Record 244 : Norfolk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 245 : Port Elizabeth
# Processing Record 246 : Cherskiy
# Processing Record 247 : Vostok
# Processing Record 248 : Qian’an
# Processing Record 249 : Acajutla
# Processing Record 250 : Dudinka
# City not found. Skipping...
# Processing Record 251 : Bahía Blanca
# Processing Record 252 : Ayan
# Processing Record 253 : Koungou
# Processing Record 254 : Esperance
# Processing Record 255 : Makakilo City
# Processing Record 256 : Torbay
# Processing Record 257 : Antofagasta
# Processing Record 258 : Port Shepstone
# City not found. Skipping...
# Processing Record 259 : Barrow
# Processing Record 260 : Port Keats
# Processing Record 261 : Turukhansk
# Processing Record 262 : Cardston
# Processing Record 263 : Comodoro Rivadavia
# Processing Record 264 : Rio Verde de Mato Grosso
# Processing Record 265 : Dauphin
# Processing Record 266 : Necochea
# Processing Record 267 : Vardø
# Processing Record 268 : Bilibino
# Processing Record 269 : Benguela
# Processing Record 270 : Rāpar
# Processing Record 271 : Longyearbyen
# Processing Record 272 : Yeppoon
# Processing Record 273 : Moyo
# Processing Record 274 : Alyangula
# Processing Record 275 : Santa Rosa
# City not found. Skipping...
# Processing Record 276 : Sisimiut
# Processing Record 277 : Medicine Hat
# Processing Record 278 : Egvekinot
# Processing Record 279 : Saint-Pierre
# Processing Record 280 : Ville-Marie
# Processing Record 281 : Hailun
# Processing Record 282 : Atar
# Processing Record 283 : Alice Springs
# City not found. Skipping...
# Processing Record 284 : Kumul
# Processing Record 285 : Ambulu
# Processing Record 286 : Dikson
# Processing Record 287 : Olhão
# Processing Record 288 : Kudahuvadhoo
# Processing Record 289 : Sioux Lookout
# Processing Record 290 : Sur
# Processing Record 291 : Ngerengere
# Processing Record 292 : Chaman
# Processing Record 293 : Bengkulu
# Processing Record 294 : Mossamedes
# Processing Record 295 : Northam
# Processing Record 296 : Port Hardy
# Processing Record 297 : Rassvet
# City not found. Skipping...
# Processing Record 298 : Forsytheganj
# Processing Record 299 : Emerald
# Processing Record 300 : Ishigaki
# Processing Record 301 : Katherine
# Processing Record 302 : Saldanha
# Processing Record 303 : Lebu
# Processing Record 304 : Sulangan
# Processing Record 305 : Talnakh
# Processing Record 306 : Ust-Maya
# Processing Record 307 : Nautla
# Processing Record 308 : Dongsheng
# Processing Record 309 : Touros
# Processing Record 310 : Holme
# Processing Record 311 : Pangnirtung
# Processing Record 312 : Mitsamiouli
# Processing Record 313 : Coahuayana Viejo
# Processing Record 314 : Meulaboh
# Processing Record 315 : Zhaoqing
# Processing Record 316 : Sampit
# Processing Record 317 : Cermeño
# City not found. Skipping...
# Processing Record 318 : Dalbandin
# City not found. Skipping...
# Processing Record 319 : Songjianghe
# Processing Record 320 : Oktyabr'skoye
# Processing Record 321 : Taywarah
# Processing Record 322 : Arrecife
# Processing Record 323 : Orizona
# Processing Record 324 : Lipin Bor
# Processing Record 325 : Banda Aceh
# Processing Record 326 : Cauquenes
# Processing Record 327 : Lagoa
# Processing Record 328 : Pevek
# City not found. Skipping...
# Processing Record 329 : Bilma
# Processing Record 330 : Satānā
# Processing Record 331 : Tougue
# Processing Record 332 : Chardara
# Processing Record 333 : Praia da Vitória
# Processing Record 334 : Mugur-Aksy
# Processing Record 335 : Verāval
# Processing Record 336 : Assens
# Processing Record 337 : Aloleng
# Processing Record 338 : Havelock
# City not found. Skipping...
# Processing Record 339 : Narsaq
# Processing Record 340 : Whakatane
# Processing Record 341 : Inírida
# Processing Record 342 : Laas
# City not found. Skipping...
# Processing Record 343 : Turan
# Processing Record 344 : Moïssala
# Processing Record 345 : Thunder Bay
# Processing Record 346 : Huejuquilla el Alto
# Processing Record 347 : Vao
# Processing Record 348 : Vanimo
# Processing Record 349 : Ojinaga
# Processing Record 350 : Princeton
# Processing Record 351 : Kieta
# City not found. Skipping...
# Processing Record 352 : Turbat
# Processing Record 353 : Sobolevo
# Processing Record 354 : Kendari
# Processing Record 355 : Kabanjahe
# Processing Record 356 : Port Lincoln
# Processing Record 357 : Erenhot
# Processing Record 358 : Vinh
# Processing Record 359 : Celendín
# Processing Record 360 : Montepuez
# Processing Record 361 : Takoradze
# Processing Record 362 : Vágur
# Processing Record 363 : Puyang
# Processing Record 364 : Lázaro Cárdenas
# Processing Record 365 : Dajal
# Processing Record 366 : Taku
# Processing Record 367 : Sidrolândia
# Processing Record 368 : Bonavista
# Processing Record 369 : Athabasca
# Processing Record 370 : Lianzhou
# Processing Record 371 : Cuxhaven
# Processing Record 372 : Kenai
# Processing Record 373 : Shibetsu
# Processing Record 374 : Batemans Bay
# City not found. Skipping...
# Processing Record 375 : Iqaluit
# Processing Record 376 : Fort Nelson
# Processing Record 377 : Merauke
# Processing Record 378 : Constitución
# Processing Record 379 : Pánuco
# City not found. Skipping...
# Processing Record 380 : Ancud
# Processing Record 381 : Kloulklubed
# Processing Record 382 : Ocampo
# Processing Record 383 : Cap Malheureux
# Processing Record 384 : Zarubino
# Processing Record 385 : Rosetta
# Processing Record 386 : Panguna
# Processing Record 387 : Gravelbourg
# Processing Record 388 : Harrismith
# Processing Record 389 : Atambua
# Processing Record 390 : Faribault
# Processing Record 391 : Tautira
# Processing Record 392 : Mount Hagen
# Processing Record 393 : Maniitsoq
# Processing Record 394 : Winneba
# Processing Record 395 : Saint Paul Harbor
# Processing Record 396 : Kiunga
# Processing Record 397 : Half Moon Bay
# Processing Record 398 : Marinette
# Processing Record 399 : Tonalá
# Processing Record 400 : Imeni Poliny Osipenko
# Processing Record 401 : Xiuyan
# Processing Record 402 : La Unión
# Processing Record 403 : Firminy
# Processing Record 404 : Chumikan
# Processing Record 405 : Cayenne
# Processing Record 406 : Cradock
# Processing Record 407 : Brisbane
# Processing Record 408 : Chimoré
# Processing Record 409 : Kyra
# Processing Record 410 : Pyryatyn
# Processing Record 411 : Mendi
# Processing Record 412 : Chicama
# Processing Record 413 : Quang Ngai
# Processing Record 414 : Nishihara
# City not found. Skipping...
# Processing Record 415 : Udachny
# Processing Record 416 : Villavicencio
# Processing Record 417 : Kailua
# Processing Record 418 : Harbour Breton
# Processing Record 419 : Paraíso
# Processing Record 420 : Wanxian
# Processing Record 421 : Hokitika
# Processing Record 422 : Lufkin
# City not found. Skipping...
# Processing Record 423 : Pitimbu
# Processing Record 424 : Tooele
# City not found. Skipping...
# Processing Record 425 : Matagami
# Processing Record 426 : Son La
# Processing Record 427 : Mezen'
# Processing Record 428 : Dosso
# Processing Record 429 : West Wendover
# Processing Record 430 : Muisne
# Processing Record 431 : Makkah al Mukarramah
# City not found. Skipping...
# Processing Record 432 : Pontes e Lacerda
# Processing Record 433 : Hamilton
# Processing Record 434 : Maposeni
# Processing Record 435 : Goba
# Processing Record 436 : Sakakah
# Processing Record 437 : Danilovka
# Processing Record 438 : Chaozhou
# Processing Record 439 : La Rioja
# Processing Record 440 : Manuk Mangkaw
# Processing Record 441 : Roald
# Processing Record 442 : Puerto Escondido
# Processing Record 443 : Dingle
# Processing Record 444 : Togur
# Processing Record 445 : Hasaki
# Processing Record 446 : Magistral'nyy
# Processing Record 447 : Peniche
# Processing Record 448 : Cham
# Processing Record 449 : Guanare
# Processing Record 450 : Beringovskiy
# Processing Record 451 : Volchansk
# Processing Record 452 : Ugoofaaru
# Processing Record 453 : Husavik
# Processing Record 454 : Lüderitz
# Processing Record 455 : Gambissara
# Processing Record 456 : Honningsvåg
# Processing Record 457 : Hammond
# Processing Record 458 : Huanren
# Processing Record 459 : Lavras
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 460 : Hidalgotitlán
# Processing Record 461 : Sri Aman
# Processing Record 462 : Sola
# Processing Record 463 : Safaga
# Processing Record 464 : Shahrud
# Processing Record 465 : Yayva
# Processing Record 466 : Yar-Sale
# Processing Record 467 : San Rafael del Sur
# Processing Record 468 : Marsh Harbour
# Processing Record 469 : Paris
# Processing Record 470 : Zeerust
# Processing Record 471 : San Patricio
# Processing Record 472 : Petropavlovka
# Processing Record 473 : Nîmes
# Processing Record 474 : Acarí
# Processing Record 475 : Antsohihy
# Processing Record 476 : Searcy
# Processing Record 477 : Cabedelo
# Processing Record 478 : Ust'-Karsk
# Processing Record 479 : Flinders
# Processing Record 480 : Mildura
# Processing Record 481 : Amberley
# Processing Record 482 : Beira
# Processing Record 483 : Bouaflé
# Processing Record 484 : Huarmey
# Processing Record 485 : Malatya Province
# Processing Record 486 : Champotón
# Processing Record 487 : São José da Coroa Grande
# Processing Record 488 : San Diego de Los Baños
# Processing Record 489 : Melfi
# Processing Record 490 : Shache
# Processing Record 491 : Teleneşti
# Processing Record 492 : The Pas
# Processing Record 493 : Mareeba
# Processing Record 494 : Broken Hill
# Processing Record 495 : Fomboni
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 496 : San Vicente
# Processing Record 497 : Campos Belos
# Processing Record 498 : Oodweyne
# Processing Record 499 : Camapuã
# Processing Record 500 : Malanje
# Processing Record 501 : Solnechnyy
# Processing Record 502 : Camopi
# Processing Record 503 : Makubetsu
# Processing Record 504 : Marabu
# Processing Record 505 : Khovd
# Processing Record 506 : Bria
# Processing Record 507 : Cururupu
# Processing Record 508 : Chapais
# City not found. Skipping...
# Processing Record 509 : Sibolga
# Processing Record 510 : Polunochnoye
# Processing Record 511 : Adrar
# Processing Record 512 : Chifeng
# Processing Record 513 : Severo-Kuril'sk
# Processing Record 514 : São João da Barra
# Processing Record 515 : Galveston
# Processing Record 516 : Leningradskiy
# Processing Record 517 : Muyezerskiy
# Processing Record 518 : Osypenko
# Processing Record 519 : Bograd
# Processing Record 520 : Yantal'
# Processing Record 521 : Saint-Augustin
# Processing Record 522 : Mumford
# Processing Record 523 : Aksarka
# Processing Record 524 : Maputo
# Processing Record 525 : Helong
# City not found. Skipping...
# Processing Record 526 : Okha
# Processing Record 527 : Yerbogachën
# Processing Record 528 : Kingston
# Processing Record 529 : Fortuna
# Processing Record 530 : Nouadhibou
# City not found. Skipping...
# Processing Record 531 : Murray Bridge
# Processing Record 532 : Batagay-Alyta
# Processing Record 533 : Sistranda
# Processing Record 534 : Honiara
# Processing Record 535 : Los Llanos de Aridane
# Processing Record 536 : Qena
# Processing Record 537 : Gamba
# Processing Record 538 : Cabo San Lucas
# Processing Record 539 : Santa Vitória do Palmar
# Processing Record 540 : Huangmei
# Processing Record 541 : Kurchum
# Processing Record 542 : Yārāda
# City not found. Skipping...
# Processing Record 543 : Portland
# City not found. Skipping...
# Processing Record 544 : Kandrian
# Processing Record 545 : Najrān
# Processing Record 546 : Okhotsk
# Processing Record 547 : San Fernando
# Processing Record 548 : Ballaghaderreen
# City not found. Skipping...
# Processing Record 549 : Abu Dhabi
# City not found. Skipping...
# Processing Record 550 : Lima
# Processing Record 551 : Manokwari
# Processing Record 552 : Lumeje
# Processing Record 553 : Wagar
# Processing Record 554 : Nizwá
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 555 : Maroantsetra
# City not found. Skipping...
# Processing Record 556 : Kruisfontein
# Processing Record 557 : Akdepe
# Processing Record 558 : Ridgecrest
# Processing Record 559 : Isabela
# Processing Record 560 : Namatanai
# Processing Record 561 : Pangody
# Processing Record 562 : Hambantota
# Processing Record 563 : Adeje
# Processing Record 564 : Coyhaique
# Processing Record 565 : Karratha

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dictionary = {
    "City": city_name,
    "Country": country,
    "Date": date,
    "Latitude": lat,
    "Longitude":lon,
    "Max Temperature": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": windspeed
}
weather_df = pd.DataFrame(weather_dictionary)
weather_df.to_csv("./output_data/weather_data.csv")

# %%
weather_df.head()
# Out:
#          City Country        Date  Latitude  Longitude  Max Temperature  \
# 0  Concarneau      FR  1635527703   47.8750    -3.9225            58.05
# 1     Mataura      NZ  1635527704  -46.1927   168.8643            48.07
# 2       Vaini      TO  1635527704  -21.2000  -175.2000            73.56
# 3   Cape Town      ZA  1635527700  -33.9258    18.4232            68.09
# 4     Rikitea      PF  1635527420  -23.1203  -134.9692            75.29
#
#    Humidity  Cloudiness  Wind Speed
# 0        71          81       12.37
# 1        99          86        3.29
# 2        94          90        8.05
# 3        70          75        3.00
# 4        76         100       18.50

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Skip - no cities with humidity over 100%

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Max Temperature"], facecolors="red",marker="o",edgecolor="black")
plt.title("City Latitude vs. Max Temperature (10/29/21)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("./output_data/Lat_vs_Max_Temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Humidity"], facecolors="orange",marker="o",edgecolor="black")
plt.title("City Latitude vs. Humidity (10/29/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig("./output_data/Lat_vs_Humid.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Cloudiness"], facecolors="grey",marker="o",edgecolor="black")
plt.title("City Latitude vs. Cloudiness (10/29/21)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig("./output_data/Lat_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Wind Speed"], facecolors="purple",marker="o",edgecolor="black")
plt.title("City Latitude vs. Wind Speed (10/29/21)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.savefig("./output_data/Lat_vs_Wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern = weather_df.loc[weather_df["Latitude"]>=0.0]
northern.reset_index(inplace=True)
southern = weather_df.loc[weather_df["Latitude"]<0.0]
southern.reset_index(inplace=True)
northern.dtypes
# Out:
# index                int64
# City                object
# Country             object
# Date                 int64
# Latitude           float64
# Longitude          float64
# Max Temperature    float64
# Humidity             int64
# Cloudiness           int64
# Wind Speed         float64
# dtype: object

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern['Latitude'])
y_values = pd.to_numeric(northern['Max Temperature'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regression_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temperature (F) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.savefig("./output_data/North_Temp_vs_Lat.png")
# Out:
# The r-squared is: -0.8757929247471702

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern['Latitude'])
y_values = pd.to_numeric(southern['Max Temperature'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regression_values,"r-")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temperature (F) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.savefig("./output_data/South_Temp_vs_Lat.png")
# Out:
# The r-squared is: 0.5655322816977255

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern['Latitude'])
y_values = pd.to_numeric(northern['Humidity'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regression_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.savefig("./output_data/North_Humid_vs_Lat.png")
# Out:
# The r-squared is: 0.31578940984662157

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern['Latitude'])
y_values = pd.to_numeric(southern['Humidity'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regression_values,"r-")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.savefig("./output_data/South_Humid_vs_Lat.png")
# Out:
# The r-squared is: 0.05041469673082807

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern['Latitude'])
y_values = pd.to_numeric(northern['Cloudiness'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regression_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.savefig("./output_data/North_Cloud_vs_Lat.png")
# Out:
# The r-squared is: 0.1734593736789784

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern['Latitude'])
y_values = pd.to_numeric(southern['Cloudiness'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regression_values,"r-")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.savefig("./output_data/South_Cloud_vs_Lat.png")
# Out:
# The r-squared is: 0.28950094598578757

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern['Latitude'])
y_values = pd.to_numeric(northern['Wind Speed'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regression_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.savefig("./output_data/North_Wind_vs_Lat.png")
# Out:
# The r-squared is: 0.20234606346915138

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern['Latitude'])
y_values = pd.to_numeric(southern['Wind Speed'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regression_values,"r-")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.savefig("./output_data/South_Wind_vs_Lat.png")
# Out:
# The r-squared is: -0.35407937698176467

# %% [markdown]
# ## Observations
# 1. There is a strong correlation between max temperature and latitude coordinates closer to the equator or 0 degrees.
# 2. There is little correlation between cloudiness and latitude.
# 3. There is also little correlation between humidity and latitude.
